# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('users_data.csv', encoding = "ISO-8859-1")

# %%
data.shape
# Out:
# (240, 9)

# %%
data.head()
# Out:
#           user_name                                         full_name  \
# 0      wqwqwq12345w                                              1998
# 1       soymuyfalsa                                     soy muy falsa
# 2    andrea_bordon_                                     andrea bordon
# 3  @ndah.endah.3701  @ndah.endah.3701 _ã¢ Instagram photos and videos
# 4   jolsuperstar_tz                                   jolsuperstartz
#
#    num_posts num_followers  num_followings is_private  is_business  \
# 0        0.0             1            12.0      False        False
# 1        5.0            62             1.0      False        False
# 2        1.0           132            78.0      False         True
# 3        3.0           798           138.0      False         True
# 4       66.0           494           195.0      False        False
#
#    is_joined_recently                                          biography
# ...

# %%
data.isnull().sum()
# Out:
# user_name                0
# full_name               42
# num_posts               42
# num_followers           42
# num_followings          42
# is_private              63
#  is_business            63
#  is_joined_recently     63
#  biography             119
# dtype: int64

# %%
data_no_nan = data[data.iloc[:,0] != 'Error']

# %%
data_no_nan.head()
# Out:
#           user_name                                         full_name  \
# 0      wqwqwq12345w                                              1998
# 1       soymuyfalsa                                     soy muy falsa
# 2    andrea_bordon_                                     andrea bordon
# 3  @ndah.endah.3701  @ndah.endah.3701 _ã¢ Instagram photos and videos
# 4   jolsuperstar_tz                                   jolsuperstartz
#
#    num_posts num_followers  num_followings is_private  is_business  \
# 0        0.0             1            12.0      False        False
# 1        5.0            62             1.0      False        False
# 2        1.0           132            78.0      False         True
# 3        3.0           798           138.0      False         True
# 4       66.0           494           195.0      False        False
#
#    is_joined_recently                                          biography
# ...

# %%
data_no_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198 entries, 0 to 200
# Data columns (total 9 columns):
# user_name              198 non-null object
# full_name              198 non-null object
# num_posts              198 non-null float64
# num_followers          198 non-null object
# num_followings         198 non-null float64
# is_private             171 non-null object
#  is_business           171 non-null object
#  is_joined_recently    171 non-null object
#  biography             120 non-null object
# dtypes: float64(2), object(7)
# memory usage: 15.5+ KB

# %%
data_no_nan.columns
# Out:
# Index(['user_name', 'full_name', 'num_posts', 'num_followers',
#        'num_followings', 'is_private', ' is_business', ' is_joined_recently',
#        ' biography'],
#       dtype='object')

# %%
data_no_nan.iloc[183,3]
# Out:
# '22.7k'

# %%
data_no_nan['num_followers_float'] = data_no_nan.apply(lambda row: float(row[3].replace('k', 'e3')), axis=1)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_no_nan
# Out:
#               user_name                                          full_name  \
# 0          wqwqwq12345w                                               1998
# 1           soymuyfalsa                                      soy muy falsa
# 2        andrea_bordon_                                      andrea bordon
# 3      @ndah.endah.3701   @ndah.endah.3701 _ã¢ Instagram photos and videos
# 4       jolsuperstar_tz                                    jolsuperstartz
# 5          wisnuhdyat33                                      WisnuHidayat
# 6          adiukulelo87         ________ _____ä_____µ__Î__µ__ª
# 7              edupdv04                                 Eduard Puigdevall
# 8              segaid98                                         Sega ID98
# 9         reza.aliakber                                     Reza Aliakbar
# 10            dairo_p10                          Dairo Perez   ))ÔÔ/M((
# 11                zj.2_                       éóè±è_è_é_ è_éÊèëèµè±è_é_é_
# ...

# %%
#eval(data_no_nan.iloc[183,3].replace('k', '*10**3'))

# %%
data_no_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198 entries, 0 to 200
# Data columns (total 10 columns):
# user_name              198 non-null object
# full_name              198 non-null object
# num_posts              198 non-null float64
# num_followers          198 non-null object
# num_followings         198 non-null float64
# is_private             171 non-null object
#  is_business           171 non-null object
#  is_joined_recently    171 non-null object
#  biography             120 non-null object
# num_followers_float    198 non-null float64
# dtypes: float64(3), object(7)
# memory usage: 27.0+ KB

# %%
data_no_nan['following_follower_ratio'] = data_no_nan['num_followings'] / (data_no_nan['num_followers_float'] +1)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_no_nan.describe()
# Out:
#          num_posts  num_followings  num_followers_float  \
# count   198.000000      198.000000           198.000000
# mean     64.126263      581.409091          1569.520202
# std     215.933810     1182.614285          3585.421366
# min       0.000000        1.000000             0.000000
# 25%       1.000000       63.250000             8.000000
# 50%       4.500000      189.000000           155.000000
# 75%      27.750000      461.500000          1018.750000
# max    2432.000000     7343.000000         24200.000000
#
#        following_follower_ratio
# count                198.000000
# mean                   9.370692
# std                   62.306907
# min                    0.003051
# 25%                    0.318273
# 50%                    1.535818
# 75%                    5.024477
# max                  872.800000

# %%
plt.hist(data_no_nan['following_follower_ratio'], bins = 80)
plt.xlim(right = 120)
plt.ylim((0, 200))
# Out:
# (0, 200)

# %%
data_no_nan[data_no_nan['following_follower_ratio'] == 872.800000]
# Out:
#     user_name          full_name  num_posts num_followers  num_followings  \
# 117  bs88888m  Snap__ªg888s8         0.0             4          4364.0
#
#     is_private  is_business  is_joined_recently  biography  \
# 117       True        False               False        NaN
#
#      num_followers_float  following_follower_ratio
# 117                  4.0                     872.8

# %%
data_no_nan
# Out:
#               user_name                                          full_name  \
# 0          wqwqwq12345w                                               1998
# 1           soymuyfalsa                                      soy muy falsa
# 2        andrea_bordon_                                      andrea bordon
# 3      @ndah.endah.3701   @ndah.endah.3701 _ã¢ Instagram photos and videos
# 4       jolsuperstar_tz                                    jolsuperstartz
# 5          wisnuhdyat33                                      WisnuHidayat
# 6          adiukulelo87         ________ _____ä_____µ__Î__µ__ª
# 7              edupdv04                                 Eduard Puigdevall
# 8              segaid98                                         Sega ID98
# 9         reza.aliakber                                     Reza Aliakbar
# 10            dairo_p10                          Dairo Perez   ))ÔÔ/M((
# 11                zj.2_                       éóè±è_è_é_ è_éÊèëèµè±è_é_é_
# ...

# %%
data_no_nan.to_csv('data_no_nan.csv', sep=',')

# %%
# Add features: tagged_by_others (y/n), time_registered, private (y/n),

# %%
from get_new_feature import *

# %%
follower_urls[20]
# Out:
# 'https://www.instagram.com/miguelrill98/'

# %%
get_new_features(follower_urls[21])
# Out:
# (False,
#  True,
#  False,
#  'Kherson\nНе бойся не когда не чего \nНе будь копией будь оригиналом\nДоверяй разссудку не верь глазам')

# %%
cd ..
# Out:
# /Users/liliying/Galvanize/instagram_fake_followers_detector

# %%
get_new_features(follower_urls[22])
# Out:
# (False, False, False, 'GINEUSE')

# %%
filename = "new_feature.csv"
f = open(filename, "w")
headers = "is_private, is_business, is_joined_recently, biography\n"
f.write(headers)
# Out:
# 55

# %%
for item in follower_urls:
    try: 
        is_private, is_business, is_joined_recently, biography = get_new_features(item)
        f.write(str(is_private) + ',' + str(is_business) + ',' + str(is_joined_recently) + ',' + str(biography.replace('\n', '').replace(',', '')) + "\n")
    except:
        f.write('NaN' + '\n')

# %%
is_private, is_business,is_joined_recently, biography = get_new_features(follower_urls[0])
f.write(str(is_private) + ',' + str(is_business) + ',' + str(is_joined_recently) + ',' + str(biography.replace('\n', '').replace(',', '')) + "\n")
# Out:
# 101

# %%
f.close()
