# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.special import comb

from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import log_loss, make_scorer
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV

# %%
from urllib.request import urlopen as uReq
import json
import time
import random
import bs4
import requests
from bs4 import BeautifulSoup
from selenium.webdriver import Chrome, Firefox
from pymongo import MongoClient

# %%
cd ..
# Out:
# /Users/liliying/Galvanize/instagram_fake_followers_detector

# %%
from src.DataPreparation import *

# %%
browser = Chrome()

# %%
url = 'http://instagram.com/instagram'

# %%
browser.get(url)

# %%
sel = "a.FPmhX"

# %%
followers = browser.find_elements_by_css_selector(sel)

# %%
last_follower = followers[-1]

# %%
scroll_to_last_follower(browser=browser)

# %%
len(followers)
# Out:
# 996

# %%
for i in range(5):
    followers = browser.find_elements_by_css_selector(sel)
    scroll_to_last_follower(browser=browser)

# %%
followers[0]
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="f272f65bcd2c991f7febddc4346b3d84", element="0.09933478550186914-37")>

# %%
follower = followers[0]
follower
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="f272f65bcd2c991f7febddc4346b3d84", element="0.09933478550186914-37")>

# %%
follower_urls = []
for follower in followers:
    follower_urls.append(follower.get_attribute('href'))

# %%
df = get_all_info(follower_urls[0])

# %%
from src.get_er import *

# %%
username = url[26:-1]
username
# Out:
# '00reisonline'

# %%
df = get_all_info(follower_urls[0])

# %%
df
# Out:
#        user_name      full_name num_posts num_followers num_following  \
# 0  _paulacortes_  Paula Cortes          2           329           331
#
#   is_private is_business is_joined_recently biography
# 0      False        True               True       🇨🇴⚡

# %%
for url in follower_urls:
    try:
        df = df.append(get_all_info(url))
    except:
        pass

# %%
df
# Out:
#                user_name                                       full_name  \
# 0          _paulacortes_                                   Paula Cortes
# 0          _paulacortes_                                   Paula Cortes
# 0               rodri_g7                                      Rodriigoo
# 0           @inpopulator      @inpopulator • Instagram photos and videos
# 0             nazwa_7288                       나는 너를 사랑해. 내 가장 친한 친구 야.
# 0          aldyfairuzzzz                                         AllFrz
# 0         denyfrimansyah                                         De Nik
# 0        alicegaltarossa                               Alice Galtarossa
# 0         katyy.guerrero                                      ❤ katy❤ 💋
# 0           younis_naimi                              Younis Naimi💪🏽💪🏽🔥
# 0       _riccardo_lessi_                                 Riccardo Lessi
# 0                ibmdq39                                         Sir Bm
# 0        reyza_syahrizal                                    reyzasyhrzl
# 0          jumanh.abayah                               عباية جمانة🧚🏻‍♀️
# 0              mrmr.8954                                         mrputo
# 0      juancarloscortell                            Juan Carlos Cortell
# 0        red_ouaane_ben_                                Redwane KoLombò
# 0        girlfromhell_17                             ❌ DANGEROUS_😈GIRL❌
# 0        alan_kanimaze06                                   Alan barwari
# 0     nathaniel.micallef                             Nathaniel Micallef
# 0           najwa_syif21                                    Najwa syifa
# 0            ale.vegetta                                    Ale Vegetta
# 0                boki.28                                          Bojan
# 0       @felipee.marques  @felipee.marques • Instagram photos and videos
# 0           hidiroglu679                               Meltem Hidiroğlu
# 0      clindile_mbhele91                                Clindile_Mbhele
# 0      captures_by_sahil                              Sahil Singh Dusaj
# 0           __joowanka__                                  ▶️XJØVÄŃKÂX◀️
# 0   emmanuel_gaher_darka                                Emmanuel Garcia
# 0           cony__chellz                                         ❤cony👑
# ..                   ...                                             ...
# 0           tobias.lueck                                           Toby
# 0             fatmaaayld                                 fatma yıldırım
# 0                  _7k1b                                       حيدر علي
# 0       pricilameirelles                                          Pri💯S
# 0           ale_il_gurri                               Alessio Gurrieri
# 0             blue4070_3                                          James
# 0          esneiderjhoel                                  ESNEIDERJHOEL
# 0           simms_dizzy1                                  Simms_Disbrow
# 0             chacoule74                                       chacoule
# 0               fabi_433                                   fabi_11_edlp
# 0         janottogresdal                               Jan Otto Gresdal
# 0               lowblach                                   Lorena Blach
# 0             55656sarah                                          Sarah
# 0                  bln1_                          NAGHAM BaniHamad -نغم
# 0      1.mohammed_shaker                                  محمد شاكر ⓜ.ⓢ
# 0       kemalsaidaydemir                             Kemal Said Aydemir
# 0              noviiaa_a                                         aries👽
# 0        barepmartrianto                         Barep Martrianto Putro
# 0               andyzb89                                 Andre 🙋🏼‍♂️✌🏻️
# 0                anark15                                   Anar Kuliev🤙
# 0            tunahan7108                                 Tunahan YALÇIN
# 0                dren982                                           dren
# 0              realmeltz                                MeltedBuiscuit4
# 0         bff_cm_slimezz                           Courtney And Miranda
# 0       youssef_ghanem17                                 YoussEf GhanEm
# 0          azizbolat9827                                     Aziz BOLAT
# 0        cx.alexandra.cx                               Alessandra Lopez
# 0         kisaogluabuzer                                Abuzer Kisaoğlu
# 0              fera2107_                                           fer🦄
# 0        khalid_bouraada                               Khalîd ßOu Rââdà
#
#    num_posts num_followers num_following is_private is_business  \
# 0          2           329           331      False        True
# 0          2           329           331      False        True
# 0          5           488           910      False       False
# 0          9          6429            59      False        True
# 0          7           176           418       True       False
# 0          5           622            96      False       False
# 0         10           205           400      False        True
# 0         55           421           577       True       False
# 0        103           614           260       True       False
# 0         52           350           195      False        True
# 0          5           556           160      False        True
# 0          0             1            17      False       False
# 0         10            93           197      False        True
# 0          9            24             1      False        True
# 0          0             0             2       True       False
# 0         34          1602           423      False       False
# 0         55          2965           785      False       False
# 0         15          2979           134       True       False
# 0         47          1872           620      False        True
# 0         47          1685           458      False       False
# 0          3           428           105       True       False
# 0       1035          9217          1110      False        True
# 0         77          2154           860       True       False
# 0        360         11.2k           414      False        True
# 0          1             8            87      False       False
# 0          1             0            38      False       False
# 0         33           352            64      False        True
# 0          7          1683           342       True       False
# 0        676           700           242      False        True
# 0          2          1068           312      False        True
# ..       ...           ...           ...        ...         ...
# 0         13         12.7k           307      False        True
# 0          1             7            18       True       False
# 0          2          5971           612      False       False
# 0        296          3057          1718      False       False
# 0         50          2791           696      False        True
# 0          0             0             5      False       False
# 0          0             0             9      False       False
# 0         53           147           615       True       False
# 0         11           191          1125      False        True
# 0         12           611           906      False        True
# 0         97           106           136      False       False
# 0        407          4845           604      False       False
# 0          1             1             3      False       False
# 0         13          1342           659      False       False
# 0         19          6914           292      False        True
# 0        130          6716           364      False        True
# 0          1           362           323      False        True
# 0          5           320           219      False       False
# 0        176         17.3k           906      False        True
# 0        258          4864           231      False        True
# 0          1            11            82      False       False
# 0          0             4            11      False       False
# 0         19           235          1001      False       False
# 0         20            74           147       True       False
# 0          2            76           220      False       False
# 0          1             8            16      False       False
# 0          0            15            56      False       False
# 0          1             9            36      False       False
# 0          0           840           176      False       False
# 0         78           615           501      False        True
#
#    is_joined_recently                                          biography
# 0                True                                                🇨🇴⚡
# 0                True                                                🇨🇴⚡
# 0               False
# 0               False  Do you need more followers?  inpopulator make ...
# 0               False
# 0               False
# 0               False                                           Follback
# 0               False                      Liceo Fermi 📚~18~💭🎶~Padova📷🌪🖼
# 0               False  CDMX\n21 años 👩\nIng. en Administración ✏📚📖\n"...
# 0               False       Paris🇫🇷/Italia 🇮🇹/GYM💪🏽/Snapchat: younis2009
# 0               False                                   XIV · VIII · MMI
# 0                True
# 0               False  FB 👉 reyza syhrzl\nWa 👉089513576803\nJakarta-i...
# 0                True                         للتواصل والاستفسار دايركت📥
# 0               False
# 0               False  🏃🏼‍♂️ Runner\n📣 Entrenador personal de alto re...
# 0               False  #-___ReDwÀnE__BenYoÜB ✋😍😘\n# FacEbOok : RedWan...
# 0               False
# 0               False  فــــــــێـــــــربـــە ژیــــانــــێ ب هــیــ...
# 0               False  From Malta..\nLove Skulls, Tattoos & Fashion.....
# 0               False  Follow akun kedua @awjan.najwasyif21\nFollow a...
# 0               False  Libertad ...es la que tiene el espíritu al rec...
# 0               False  "Don't stop pushing yourself, you have the pow...
# 0               False  24 y         | Rio de Janeiro 🇧🇷          | Ru...
# 0                True  📍 @onyx_makeup \n✖️ @charlotte.mcintyre\n✖️ @c...
# 0                True
# 0               False  📍 New Delhi\nLive life,take pictures, relive m...
# 0               False  l17l💫\n✖️RVA💙\n▶️GRESNA ZIVA⚕️\n◀️Bez Saźaljen...
# 0               False  ||♠♥mago♣♦||💙UNITEC💙||F: Emmanuel Garcia Darka...
# 0               False                               santiago📍\nsoltera 😈
# ..                ...                                                ...
# 0               False  Certificated Personal Trainer 💪🏻\nCertificated...
# 0                True                                 K7AÜ\nYeni hesap 😉
# 0               False  ⠀⠀\n⠀\n⠀\n⠀ ‏ ⠀⠀⠀⠀⠀\n‏⠀ ⠀⠀⠀⠀⠀ \n‏⠀⠀⠀⠀⠀\n‏ ⠀⠀⠀⠀...
# 0               False
# 0               False  ∆I'm  The cult of personality∆❌🔥\n🌁Turin🌃🌀🌠\n#...
# 0                True
# 0                True
# 0               False                              God,Family,Basketball
# 0               False             #Plus militaire que mercenaire le duc@
# 0               False
# 0               False
# 0               False  Fashion Designer\nFootwear & Accessories Speci...
# 0                True
# 0               False                          HKJ 🇯🇴/\nVibrant flora 🖤.
# 0               False                  My second account --->@m.s___2001
# 0               False  🇹🇷🇩🇪  #fitness #travel Schöne Tage kommen nich...
# 0               False  🎓MAN 01 Cilacap\n📍Follback?dm\n📍+62\n📍You have...
# 0               False    Memayu Hayuning Bawono, Lebur Dining Pangestuti
# 0               False  🇩🇪🎓  \n✈️ 🌏 👫\n🐶😍\n🏋️‍♀️ 💪🏻 \nCooperations ⬇️\...
# 0               False  Love sports especially football @juventus ⚫⚪  ...
# 0                True  🇿🇦/🇦🇺 Following big dreams 🏀❤️ @sindi__xo was ...
# 0                True
# 0               False  Email 📧 RealMeltZ@gmail.com Xbox@MeltedBuiscui...
# 0               False
# 0               False  I May Be Crazy.. Don't Mind Me..😊..\nTV Shows....
# 0                True  💥BLAKE AUSTIN \n🏋🏻‍♂️-Coach @holdfast_training...
# 0                True  🥰izabel🥰daphy🥰suzie🥰yahani🥰lucy🥰kris🥰jesse🥰jul...
# 0                True        Molloy '21 😴 // 🏈 #13 sc: Anthonyvargas41 😉
# 0               False  🌜Fera novita amelya🌛\n💋follow+spamlike 👉flbck\...
# 0               False  I love❤️ Drawing ✍🏻.\n♡_♡\n FucK_The_WorLD🖕🏻\n...
#
# [184 rows x 9 columns]

# %%
df
